# %%
import numpy as np
import pandas as pd

# %%
# Load in the prescriber info dataset 
prescriber_dataset = pd.read_csv('../RawData/prescriber-info.csv')

# %%
#Create two datasets - one for those who prescribed opioids and one for those who didnt 
opioid_prescribers = prescriber_dataset.loc[prescriber_dataset['Opioid.Prescriber']==1]
non_opioid_prescribers = prescriber_dataset.loc[prescriber_dataset['Opioid.Prescriber']==0]

# erase prescriber_dataset
del prescriber_dataset

# %%
print (str(opioid_prescribers.shape[0]) + ' opioid prescribers')
print (str(non_opioid_prescribers.shape[0]) + ' non opioid prescribers')
# Out:
# 14688 opioid prescribers
# 10312 non opioid prescribers

# %%
opioid_prescribers.dtypes.value_counts()
# Out:
# int64     252
# object      4
# dtype: int64

# %%
opioid_prescribers.groupby('Gender').count()
# Out:
#          NPI  State  Credentials  Specialty  ABILIFY  ACETAMINOPHEN.CODEINE  \
# Gender
# F       5135   5135         4962       5135     5135                   5135
# M       9553   9553         9319       9553     9553                   9553
#
#         ACYCLOVIR  ADVAIR.DISKUS  AGGRENOX  ALENDRONATE.SODIUM  \
# Gender
# F            5135           5135      5135                5135
# M            9553           9553      9553                9553
#
#               ...          VERAPAMIL.ER  VESICARE  VOLTAREN  VYTORIN  \
# Gender        ...
# F             ...                  5135      5135      5135     5135
# M             ...                  9553      9553      9553     9553
#
#         WARFARIN.SODIUM  XARELTO  ZETIA  ZIPRASIDONE.HCL  ZOLPIDEM.TARTRATE  \
# Gender
# F                  5135     5135   5135             5135               5135
# M                  9553     9553   9553             9553               9553
#
#         Opioid.Prescriber
# Gender
# ...

# %%
pd.value_counts(opioid_prescribers['Gender'].values, sort=False)
# Out:
# F    5135
# M    9553
# dtype: int64

# %%
opioid_prescribers.groupby('State').count()
# Out:
#         NPI  Gender  Credentials  Specialty  ABILIFY  ACETAMINOPHEN.CODEINE  \
# State
# AE        2       2            2          2        2                      2
# AK       27      27           27         27       27                     27
# AL      244     244          241        244      244                    244
# AR      159     159          151        159      159                    159
# AZ      331     331          321        331      331                    331
# CA     1462    1462         1427       1462     1462                   1462
# CO      256     256          245        256      256                    256
# CT      202     202          198        202      202                    202
# DC       35      35           31         35       35                     35
# DE       51      51           48         51       51                     51
# FL      875     875          856        875      875                    875
# ...

# %%
opioid_prescribers.count(GeneratorExi)
# Out:
# NPI                               14688
# Gender                            14688
# State                             14688
# Credentials                       14281
# Specialty                         14688
# ABILIFY                           14688
# ACETAMINOPHEN.CODEINE             14688
# ACYCLOVIR                         14688
# ADVAIR.DISKUS                     14688
# AGGRENOX                          14688
# ALENDRONATE.SODIUM                14688
# ALLOPURINOL                       14688
# ALPRAZOLAM                        14688
# AMIODARONE.HCL                    14688
# AMITRIPTYLINE.HCL                 14688
# AMLODIPINE.BESYLATE               14688
# AMLODIPINE.BESYLATE.BENAZEPRIL    14688
# AMOXICILLIN                       14688
# AMOX.TR.POTASSIUM.CLAVULANATE     14688
# AMPHETAMINE.SALT.COMBO            14688
# ATENOLOL                          14688
# ATORVASTATIN.CALCIUM              14688
# AVODART                           14688
# ...

# %%
# Read in dataset that contains the number of opioid prescriptions per year 
df = pd.read_csv('../RawData/Opioid analgesic prescriptions dispensed from US retail pharmacies, Q4 2009-Q2 2015.csv')

# Split quarter to Q4 / Year and create new columns (theyre appended at the end if you print the df out and try to find it)
df["Quarter1"], df["Year"] = zip(*df["Quarter"].str.split().tolist())

#Delete the quarter column
del df["Quarter"]

# %%
# Out:
#     Hydrocodone  Oxycodone  Tramadol  Morphine  Fentanyl  H+O+T+M+F  \
# 0      30831801   12598334   6475986   1731324   1266443   52903888
# 1      30692922   12676513   6429833   1727199   1240702   52767169
# 2      31554204   13282829   6694127   1792189   1274043   54597392
# 3      32000678   13748219   6811394   1833943   1283203   55677437
# 4      32239057   13825106   7453897   1889202   1287753   56695015
# 5      32497676   13697064   7934498   1904519   1271533   57305290
# 6      32906191   13972641   8194032   1932387   1290096   58295347
# 7      32970249   14129677   8461645   1959390   1296659   58817620
# 8      32557588   14015327   8426827   1985884   1292906   58278532
# 9      32821380   13676982   9085356   1967390   1256587   58807695
# 10     32883231   13799118   9373129   2014571   1270489   59340538
# 11     32621466   13714150   9556588   2021396   1267369   59180969
# 12     32429704   13810577   9753897   2058168   1273738   59326084
# ...
